# %%
# Reproduction
bert_acc: float = 0.674
bert_f1_macro: float = 0.673


# Naive Baselines
## LogReg
logreg_acc: float = 0.590
logreg_f1_macro: float = 0.570
logreg_precision_macro: float = 0.670
logreg_recall_macro: float = 0.620

## Naive Bayes
naive_bayes_acc: float = 0.520
naive_bayes_f1_macro: float = 0.510
naive_bayes_precision_macro: float = 0.50
naive_bayes_recall_macro: float = 0.530

## BiLSTM
bilstm_accuracy: float = 0.580
bilstm_f1_macro: float = 0.580
bilstm_precision_macro: float = 0.600
bilstm_recall_macro: float = 0.590


# ModernBERT
## Approach 1
modernbert_1_tpr: float = 0.804
modernbert_1_tnr: float = 0.519
modernbert_1_acc: float = 0.650
modernbert_1_f1_macro: float = 0.646
modernbert_1_precision_macro: float = 0.671
modernbert_1_recall_macro: float = 0.661



# Approach 2
modernbert_2_tpr: float = 0.603
modernbert_2_tnr: float = 0.795
modernbert_2_acc: float = 0.690
modernbert_2_f1_macro: float = 0.690
modernbert_2_precision_macro: float = 0.702
modernbert_2_recall_macro: float = 0.699



# Approach 3
modernbert_3_tpr: float = 0.630
modernbert_3_tnr: float = 0.735
modernbert_3_acc: float = 0.678
modernbert_3_f1_macro: float = 0.678
modernbert_3_precision_macro: float = 0.682
modernbert_3_recall_macro: float = 0.683



# Approach 4
modernbert_4_tpr: float = 0.675
modernbert_4_tnr: float = 0.708
modernbert_4_acc: float = 0.690
modernbert_4_f1_macro: float = 0.689
modernbert_4_precision_macro: float = 0.690
modernbert_4_recall_macro: float = 0.692



# Approach 5
modernbert_5_tpr: float = 0.648
modernbert_5_tnr: float = 0.753
modernbert_5_acc: float = 0.696
modernbert_5_f1_macr1: float = 0.695
modernbert_5_precision_macro: float = 0.700
modernbert_5_recall_macro: float = 0.700
